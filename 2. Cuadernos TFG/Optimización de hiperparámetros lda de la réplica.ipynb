# %%
# Tratamiento de datos
# ==============================================================================
import pandas as pd
import numpy as np

# Gráficos
# ==============================================================================
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
plt.style.use("bmh")
plt.style.use('ggplot')

# Preprocesado y modelado
# ==============================================================================
from sklearn.impute   import SimpleImputer
import optuna
import shap
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics  import roc_auc_score

# %% [markdown]
# Importo en un dataframe la cohorte de datos

# %%
df_data = pd.read_csv('./data/data.csv', sep = ";")
df_data.index.name = 'idMuestra'
df_data.head(3)
# Out:
#              IDInm       NH  AntiN  AntiS  AntiM  age  gender  score  \
# idMuestra
# 0          1407962  3084327    NaN    NaN    NaN   88       1    NaN
# 1          1407963   587116    NaN    NaN    NaN   46       0    NaN
# 2          1408025   764584    NaN    NaN    NaN   82       0    3.0
#
#            Line Timepoint  Timepoint  ...  TH27p28n  TH27n28n  CTLDRn38n  \
# idMuestra                             ...
# 0                     NaN        0.0  ...  0.007514  0.037952   0.075808
# 1                     NaN        0.0  ...  0.001384  0.000951   0.057471
# 2                     1.0        1.0  ...  0.027458  0.085781   0.232804
#
#            CTLDRp38n  CTLDRn38p  CTLDRp38p  THDRn38n  THDRp38n  THDRn38p  \
# idMuestra
# 0           0.064660   0.638796   0.220736  0.046994  0.024834  0.879776
# 1           0.014049   0.826309   0.102171  0.035378  0.003979  0.938587
# 2           0.037037   0.221164   0.508995  0.255428  0.018838  0.628991
#
#             THDRp38
# idMuestra
# 0          0.048395
# 1          0.022057
# 2          0.096743
#
# [3 rows x 97 columns]

# %% [markdown]
# En el trabajo que vamos a replicar, se escogen los datos entre Abril y Octubre de 2020 y que hayan dado positivo en prueba PCR. Además descartamos los que no tienen score.

# %%
df_datos = df_data.copy()

# Descartamos los datos nulos o vacíos en el campo "score"
df_datos = df_datos[~df_datos[df_datos.columns[7]].isnull()]

# Descartamos los datos nulos o vacíos en el campo "fechaPCRpos" o los que son negativos "NEG"
df_datos = df_datos[~df_datos[df_datos.columns[19]].isnull()]
df_datos = df_datos[df_datos['fechaPCRpos'] != 'NEG']

# Escogemos los datos entre Abril y Octubre 2020
df_datos['fechaPCRpos'] = df_datos['fechaPCRpos'].astype('int64')
fechas = pd.to_datetime(df_datos['fechaPCRpos'], unit='D', origin='1899-12-30')
df_datos['FechaPCR'] = fechas
df_datos = df_datos[df_datos['FechaPCR'] < '2020-11-01']

# %% [markdown]
# Escojo las variables que quiero utilizar y las meto en otro dataframe

# %%
df_datos = df_datos[['score','age','ferritina','DimD','LINF ABS','C4','MoNOclasicos','TH27n28n']]
df_datos.shape
# Out:
# (155, 8)

# %%
feature_names = df_datos.drop(columns = 'score').columns.values

# %% [markdown]
# Compruebo el número de nulos (NaN) de cada variable

# %%
df_datos.isnull().sum()
# Out:
# score            0
# age              0
# ferritina        7
# DimD             6
# LINF ABS         1
# C4               3
# MoNOclasicos    29
# TH27n28n        16
# dtype: int64

# %%
# Identificamos los valores NaN visualmente
sns.heatmap(df_datos.isnull(), cbar=False)
# Out:
# <Axes: ylabel='idMuestra'>

# %% [markdown]
# Convierto la multivariable score en 2 variables: 0 Leve y 1 Moderado/Severo

# %%
df_datos['score'] = np.where(df_datos['score'] > 1, 1, 0)

print("Número de observaciones por clase")
print(df_datos['score'].value_counts())
print("")

print("Porcentaje de observaciones por clase")
print(100 * df_datos['score'].value_counts(normalize=True))
# Out:
# Número de observaciones por clase
# score
# 1    82
# 0    73
# Name: count, dtype: int64
#
# Porcentaje de observaciones por clase
# score
# 1    52.903226
# 0    47.096774
# Name: proportion, dtype: float64

# %% [markdown]
# Creo los dataframes de entrenamiento (X) y de test (y)

# %%
# Imputamos media
mean_impute  = SimpleImputer(strategy='mean')
imputed_data = mean_impute.fit_transform(df_datos)
imputed_data = pd.DataFrame(imputed_data, columns = df_datos.columns)

# %%
X = imputed_data.drop(columns = 'score').to_numpy()
y = imputed_data['score'].to_numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state=1, stratify=y)

# %%
# Definición de la función objetivo para Optuna
def objective(trial):
    # Definición de los hiperparámetros a ajustar
    solver = trial.suggest_categorical("solver", ["lsqr", "eigen"])
    shrinkage = trial.suggest_float("shrinkage", 0, 1)
    tol = trial.suggest_float("tol", 0, 1)

    # Creación del modelo LDA con los hiperparámetros sugeridos por Optuna
    model = LinearDiscriminantAnalysis(solver=solver, shrinkage=shrinkage, tol=tol)

    # Ajuste del modelo en el conjunto de entrenamiento
    model.fit(X_train, y_train)

    # Evaluación del modelo en el conjunto de prueba
    #accuracy = model.score(X_test, y_test)
    #return accuracy

    y_pred = model.predict_proba(X_test)
    roc = roc_auc_score(y_test, y_pred[:,1])
    return roc

# %%
study = optuna.create_study(direction='maximize') # maximize accuracy
study.optimize(objective, n_trials=100)
# Out:
# [I 2023-07-05 11:59:14,256] A new study created in memory with name: no-name-f871d264-b8ac-4cf6-bbb0-428cbb9c743a
# [I 2023-07-05 11:59:14,273] Trial 0 finished with value: 0.7541666666666667 and parameters: {'solver': 'eigen', 'shrinkage': 0.571487649794512, 'tol': 0.6227782064455135}. Best is trial 0 with value: 0.7541666666666667.
# [I 2023-07-05 11:59:14,287] Trial 1 finished with value: 0.6958333333333333 and parameters: {'solver': 'eigen', 'shrinkage': 0.9914588101747936, 'tol': 0.787450860198234}. Best is trial 0 with value: 0.7541666666666667.
# [I 2023-07-05 11:59:14,300] Trial 2 finished with value: 0.7125 and parameters: {'solver': 'lsqr', 'shrinkage': 0.8848866502757581, 'tol': 0.6418241336365654}. Best is trial 0 with value: 0.7541666666666667.
# [I 2023-07-05 11:59:14,314] Trial 3 finished with value: 0.775 and parameters: {'solver': 'eigen', 'shrinkage': 0.1615272086657421, 'tol': 0.5215815127299194}. Best is trial 3 with value: 0.775.
# [I 2023-07-05 11:59:14,326] Trial 4 finished with value: 0.7666666666666667 and parameters: {'solver': 'lsqr', 'shrinkage': 0.37304366581835513, 'tol': 0.27712303530865}. Best is trial 3 with value: 0.775.
# [I 2023-07-05 11:59:14,340] Trial 5 finished with value: 0.75 and parameters: {'solver': 'eigen', 'shrinkage': 0.6894186354926619, 'tol': 0.25815980818923046}. Best is trial 3 with value: 0.775.
# [I 2023-07-05 11:59:14,353] Trial 6 finished with value: 0.7541666666666667 and parameters: {'solver': 'lsqr', 'shrinkage': 0.5789976660279327, 'tol': 0.01827140360936208}. Best is trial 3 with value: 0.775.
# [I 2023-07-05 11:59:14,368] Trial 7 finished with value: 0.725 and parameters: {'solver': 'eigen', 'shrinkage': 0.8498609764009268, 'tol': 0.15465774952290356}. Best is trial 3 with value: 0.775.
# [I 2023-07-05 11:59:14,382] Trial 8 finished with value: 0.7541666666666667 and parameters: {'solver': 'eigen', 'shrinkage': 0.6749512500852783, 'tol': 0.844079093967211}. Best is trial 3 with value: 0.775.
# [I 2023-07-05 11:59:14
. Best is trial 12 with value: 0.7791666666666667.
# [I 2023-07-05 11:59:18,730] Trial 78 finished with value: 0.7791666666666667 and parameters: {'solver': 'lsqr', 'shrinkage': 0.31634929870692696, 'tol': 0.5550670804055808}. Best is trial 12 with value: 0.7791666666666667.
# [I 2023-07-05 11:59:18,794] Trial 79 finished with value: 0.7666666666666667 and parameters: {'solver': 'eigen', 'shrinkage': 0.37796731672023404, 'tol': 0.4842609685010819}. Best is trial 12 with value: 0.7791666666666667.
# [I 2023-07-05 11:59:18,859] Trial 80 finished with value: 0.7791666666666667 and parameters: {'solver': 'lsqr', 'shrinkage': 0.2796490733920252, 'tol': 0.6035269610049689}. Best is trial 12 with value: 0.7791666666666667.
# [I 2023-07-05 11:59:18,923] Trial 81 finished with value: 0.7791666666666667 and parameters: {'solver': 'lsqr', 'shrinkage': 0.24357120673825733, 'tol': 0.2746345404404321}. Best is trial 12 with value: 0.7791666666666667.
# [I 2023-07-05 11:59:18,987] Trial 82 finished with value: 0.7791666666666667 and parameters: {'solver': 'lsqr', 'shrinkage': 0.31645865983733623, 'tol': 0.3299672920180079}. Best is trial 12 with value: 0.7791666666666667.
# [I 2023-07-05 11:59:19,052] Trial 83 finished with value: 0.775 and parameters: {'solver': 'lsqr', 'shrinkage': 0.15379117077847193, 'tol': 0.35668539314363856}. Best is trial 12 with value: 0.7791666666666667.
# [I 2023-07-05 11:59:19,118] Trial 84 finished with value: 0.775 and parameters: {'solver': 'lsqr', 'shrinkage': 0.35151371895475353, 'tol': 0.29644746529070093}. Best is trial 12 with value: 0.7791666666666667.
# [I 2023-07-05 11:59:19,186] Trial 85 finished with value: 0.7791666666666667 and parameters: {'solver': 'lsqr', 'shrinkage': 0.248861422114373, 'tol': 0.43576607894645536}. Best is trial 12 with value: 0.7791666666666667.
# [I 2023-07-05 11:59:19,253] Trial 86 finished with value: 0.775 and parameters: {'solver': 'lsqr', 'shrinkage': 0.2124649169450791, 'tol': 0.2166193772212638}. Best is trial 12 with value: 0.7791666666666667.
# [I 2023-07-05 11:59:19,316] Trial 87 finished with value: 0.7791666666666667 and parameters: {'solver': 'lsqr', 'shrinkage': 0.2741003845725583, 'tol': 0.38937268965243366}. Best is trial 12 with value: 0.7791666666666667.
# [I 2023-07-05 11:59:19,380] Trial 88 finished with value: 0.7791666666666667 and parameters: {'solver': 'lsqr', 'shrinkage': 0.3184631820236258, 'tol': 0.3209031938973189}. Best is trial 12 with value: 0.7791666666666667.
# [I 2023-07-05 11:59:19,445] Trial 89 finished with value: 0.7583333333333333 and parameters: {'solver': 'lsqr', 'shrinkage': 0.42698905047027014, 'tol': 0.4659408723131378}. Best is trial 12 with value: 0.7791666666666667.
# [I 2023-07-05 11:59:19,512] Trial 90 finished with value: 0.7708333333333334 and parameters: {'solver': 'eigen', 'shrinkage': 0.36407628205798975, 'tol': 0.34738281492675716}. Best is trial 12 with value: 0.7791666666666667.
# [I 2023-07-05 11:59:19,583] Trial 91 finished with value: 0.7791666666666667 and parameters: {'solver': 'lsqr', 'shrinkage': 0.2256451423756194, 'tol': 0.5218391068357006}. Best is trial 12 with value: 0.7791666666666667.
# [I 2023-07-05 11:59:19,648] Trial 92 finished with value: 0.7791666666666667 and parameters: {'solver': 'lsqr', 'shrinkage': 0.2913735581226023, 'tol': 0.49662418294985444}. Best is trial 12 with value: 0.7791666666666667.
# [I 2023-07-05 11:59:19,714] Trial 93 finished with value: 0.7791666666666667 and parameters: {'solver': 'lsqr', 'shrinkage': 0.2509509535243962, 'tol': 0.43640864251791855}. Best is trial 12 with value: 0.7791666666666667.
# [I 2023-07-05 11:59:19,779] Trial 94 finished with value: 0.7791666666666667 and parameters: {'solver': 'lsqr', 'shrinkage': 0.30451331073437204, 'tol': 0.2917005001171578}. Best is trial 12 with value: 0.7791666666666667.
# [I 2023-07-05 11:59:19,844] Trial 95 finished with value: 0.7791666666666667 and parameters: {'solver': 'lsqr', 'shrinkage': 0.3342143287186725, 'tol': 0.40116740992974287}. Best is trial 12 with value: 0.7791666666666667.
# [I 2023-07-05 11:59:19,908] Trial 96 finished with value: 0.7791666666666667 and parameters: {'solver': 'lsqr', 'shrinkage': 0.1830664863040618, 'tol': 0.382630987482053}. Best is trial 12 with value: 0.7791666666666667.
# [I 2023-07-05 11:59:19,973] Trial 97 finished with value: 0.7791666666666667 and parameters: {'solver': 'lsqr', 'shrinkage': 0.2119159729538841, 'tol': 0.2615573430010164}. Best is trial 12 with value: 0.7791666666666667.
# [I 2023-07-05 11:59:20,039] Trial 98 finished with value: 0.7541666666666667 and parameters: {'solver': 'lsqr', 'shrinkage': 0.39395208563625533, 'tol': 0.4532818061689928}. Best is trial 12 with value: 0.7791666666666667.
# [I 2023-07-05 11:59:20,104] Trial 99 finished with value: 0.7791666666666667 and parameters: {'solver': 'lsqr', 'shrinkage': 0.2751544992563032, 'tol': 0.32129793345874025}. Best is trial 12 with value: 0.7791666666666667.

# %%
# Obtención de los mejores hiperparámetros encontrados
best_trial = study.best_trial
print("Mejores hiperparámetros encontrados:", best_trial.params)
# Out:
# Mejores hiperparámetros encontrados: {'solver': 'lsqr', 'shrinkage': 0.2736705391861307, 'tol': 0.4480414816433831}

# %%
# Ajuste del modelo con los mejores hiperparámetros encontrados
best_model = LinearDiscriminantAnalysis(**best_trial.params)
best_model.fit(X_train, y_train)
# Out:
# LinearDiscriminantAnalysis(shrinkage=0.2736705391861307, solver='lsqr',
#                            tol=0.4480414816433831)

# %%
# Evaluación del modelo en el conjunto de prueba
print("Exactitud del modelo en el conjunto de prueba:", round(best_trial.value * 100, 2), '%')
# Out:
# Exactitud del modelo en el conjunto de prueba: 77.92 %

# %%
# Extraemos los valores de Shap
explainer   = shap.explainers.Linear(best_model, X_train)
shap_values = explainer.shap_values(X_train)

# %%
# Contribución media de las características por cada clase
plt.title('Contribución media de las características por cada clase')
shap.summary_plot(shap_values, X_train, feature_names, plot_type="bar")

# %%
# Gráfico de contribución de características según valor
plt.title('Contribución de características según valor')
shap.summary_plot(shap_values, X_train, feature_names, plot_size = (15,10))
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
